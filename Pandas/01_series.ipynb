# %% [markdown]
# ## Pandas

# %%
import  numpy as nb
import  pandas as pd

# %%
labes = ['a','b','c']
my_data = [10,20,30]
arr = nb.array(my_data)
d = {'a':10,'b':20,'c':30}

# %%
pd.Series(my_data)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(my_data, index= labes)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(arr)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64
